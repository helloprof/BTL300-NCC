# %% [markdown]
# <a href="https://colab.research.google.com/github/helloprof/BTL300-NCC/blob/main/Stats1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #Statistics Plotting

# %% [markdown]
# Normal Distribution Test

# %%
# normal distribution
# !pip install matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
# plt.show()

# %% [markdown]
# Dataframes

# %%
# reading in data
import pandas as pd

url = "https://data.cdc.gov/api/views/hfr9-rurv/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(url)
# Out:
# (284142, 31)

# %%
df.head(20)
# question_df = df["Question"] == 'Percentage of older adults who are experiencing frequent mental distress'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-03c084576980> in <cell line: 0>()
#       2 question_df = df["Question"] == 'Percentage of older adults who are experiencing frequent mental distress'
#       3
# ----> 4 question_df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# data frame summary
# df.head()
# df.shape
df.describe()
# df.sample()
# Out:
#            YearStart        YearEnd     Data_Value  Data_Value_Alt  \
# count  284142.000000  284142.000000  192808.000000   192808.000000
# mean     2018.596065    2018.657735      37.676757       37.676757
# std         2.302815       2.360105      25.213484       25.213484
# min      2015.000000    2015.000000       0.000000        0.000000
# 25%      2017.000000    2017.000000      15.900000       15.900000
# 50%      2019.000000    2019.000000      32.800000       32.800000
# 75%      2021.000000    2021.000000      56.900000       56.900000
# max      2022.000000    2022.000000     100.000000      100.000000
#
#        Low_Confidence_Limit  High_Confidence_Limit     LocationID
# count         192597.000000          192597.000000  284142.000000
# mean              33.027824              42.595333     800.322677
# std               24.290016              26.156408    2511.564977
# min               -0.700000               1.300000       1.000000
# ...

# %%
filtered_df = df[["LocationDesc","Data_Value"]]
# age groups:
# filtered_df = df[["StratificationID1","Data_Value"]]

filtered_df = filtered_df.dropna()
# row_count_before = len(filtered_df)
# row_count_before
# row_count_after = len(filtered_df.dropna())
# row_count_after
filtered_df.describe()
# Out:
#           Data_Value
# count  192808.000000
# mean       37.676757
# std        25.213484
# min         0.000000
# 25%        15.900000
# 50%        32.800000
# 75%        56.900000
# max       100.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Data_Value'].plot(kind='hist', bins=20, title='Data_Value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Data_Value'].plot(kind='line', figsize=(8, 4), title='Data_Value')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#  exploring the unique values throughout the data

# unique_values = df["StratificationID1"].unique()
# unique_values
unique_values = df["LocationDesc"].unique()
unique_values
# Out:
# array(['Pennsylvania', 'South Dakota', 'Idaho', 'Maryland', 'Wisconsin',
#        'Iowa', 'Oklahoma', 'Arizona', 'Ohio', 'South', 'Nevada',
#        'Georgia', 'Northeast', 'Colorado', 'Oregon', 'Arkansas',
#        'New York', 'United States, DC & Territories', 'Puerto Rico',
#        'Guam', 'Kansas', 'Washington', 'Vermont', 'Hawaii',
#        'District of Columbia', 'Alaska', 'New Hampshire', 'Montana',
#        'New Mexico', 'Alabama', 'Louisiana', 'Kentucky', 'Utah',
#        'New Jersey', 'Tennessee', 'Maine', 'Texas', 'West Virginia',
#        'Mississippi', 'Rhode Island', 'Virginia', 'Nebraska',
#        'California', 'Illinois', 'Connecticut', 'North Dakota',
#        'Massachusetts', 'Florida', 'South Carolina', 'North Carolina',
#        'Wyoming', 'West', 'Midwest', 'Michigan', 'Virgin Islands',
#        'Missouri', 'Delaware', 'Minnesota', 'Indiana'], dtype=object)

# %% [markdown]
# #PLOTTING

# %%
# bar plot

import matplotlib.pyplot as plt
import seaborn as sns

# Sets the style of the bar charts
sns.set_theme(style="whitegrid", color_codes=True)
sns.set_theme(style="whitegrid", color_codes=True)

# Title
plt.title("Counts of Questions Asked", fontsize=20)

# Plots a vertical bar chart
plot = sns.countplot(x="LocationDesc", color="b", data=filtered_df)

# Saves the image
# plt.savefig("verticalbarchart.png")
plt.setp(plot.get_xticklabels(), rotation=90)

# Shows the image
plt.show()
